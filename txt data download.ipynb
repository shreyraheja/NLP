# %% [markdown]
# <b>Import SEC filings from wiki page</b>

# %%
import pandas as pd
import pdb
import time
import numpy as np
import scipy
import sklearn
final_date = pd.to_datetime('2004-1-30')
import matplotlib.pyplot as plt
import sys
from datetime import timedelta
from dateutil.relativedelta import relativedelta
from sklearn.metrics import confusion_matrix, accuracy_score, precision_recall_fscore_support
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn import svm
from sklearn.linear_model import Lasso
import datetime
from scipy import stats

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
response = requests.get(url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')

# %%
soup = BeautifulSoup(response.content, 'lxml')

# %%
doc_table=soup.find_all('table')

# %%
url_list=[]

# %%
from time import sleep

# %% [markdown]
# <b>Saving Txt files

# %%
for row in doc_table[0].find_all('tr')[7:]:
    cols=row.find_all('td')
    if len(cols)!=0:
        url=(cols[2].find('a')['href']+'&type=10-k')
        ticker=cols[0].get_text().strip('\n')
        soup=BeautifulSoup(requests.get(url = url).content,'html.parser')
        ten_k_list_table=soup.find_all('table')[2]
        for j in ten_k_list_table.find_all('tr'):
            cols_j=j.find_all('td')
            if len(cols_j)!=0:
                date=cols_j[3].get_text()
                url_2='https://www.sec.gov/'+(cols_j[1].find('a', {'href':True, 'id':'documentsbutton'}))['href']
                soup=BeautifulSoup(requests.get(url = url_2).content,'html.parser')
                doc_list_table=soup.find_all('table')[0]
                txt_url=doc_list_table.find_all('tr')[-1].find_all('td')[2].find('a')['href']
                with open(ticker+" @"+date +'.txt', "wb") as f:
                    f.write(requests.get('https://www.sec.gov/'+txt_url).content)
                sleep(3)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000002695ACA9148>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='www.sec.gov', port=443): Max retries exceeded with url: //Archives/edgar/data/2488/0000891618-94-000068.txt (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002695ACA9148>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-183-5e0248575017> in <module>
#      15                 txt_url=doc_list_table.find_all('tr')[-1].find_all('td')[2].find('a')['href']
#      16                 with open(ticker+" @"+date +'.txt', "wb") as f:
# ---> 17                     f.write(requests.get('https://www.sec.gov/'+txt_url).content)
#      18                 sleep(3)
#      19
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.sec.gov', port=443): Max retries exceeded with url: //Archives/edgar/data/2488/0000891618-94-000068.txt (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002695ACA9148>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))

# %%
row.get_text()
# Out:
# '\nAAP\n\nAdvance Auto Parts\nreports\nConsumer Discretionary\nAutomotive Retail\nRaleigh, North Carolina\n2015-07-09\n0001158449\n1932\n'

# %% [markdown]
# <b> Using CIKS for files other than wiki

# %%
p=open(ticker+date+".txt",'r')

# %%
requests.get(url = url).content.find_all('table')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-baed995e8328> in <module>
# ----> 1 requests.get(url = url).content.find_all('table')[2]
#
# AttributeError: 'bytes' object has no attribute 'find_all'

# %%
doc_list_table.find_all('tr')[1].find_all('td')[2].find('a')['href']
# Out:
# '/Archives/edgar/data/66740/'

# %%
p=requests.get(url = 'https://www.sec.gov/'+doc_list_table.find_all('tr')[-1].find_all('td')[2].find('a')['href'])

# %%
r = requests.get("https://www.sec.gov//Archives/edgar/data/66740/0000066740-94-000007.txt")

with open("data.txt", "wb") as f:
    f.write(r.content)
# Out:
# b'-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nProc-Type: 2001,MIC-CLEAR\nOriginator-Name: keymaster@town.hall.org\nOriginator-Key-Asymmetric:\n MFkwCgYEVQgBAQICAgADSwAwSAJBALeWW4xDV4i7+b6+UyPn5RtObb1cJ7VkACDq\n pKb9/DClgTKIm08lCfoilvi9Wl4SODbR1+1waHhiGmeZO8OdgLUCAwEAAQ==\nMIC-Info: RSA-MD5,RSA,\n JVgbB6Bp1gUxD3asThb1NrOvOn5bJ2JmwE03LjU7CkLjmqq6jr9aByx4xFtFvf4u\n 4Q6CqMnjczNfKYfNXtgolA==\n\n<IMS-DOCUMENT>0000066740-94-000007.txt : 19940308\n<IMS-HEADER>0000066740-94-000007.hdr.sgml : 19940308\nACCESSION NUMBER:\t\t0000066740-94-000007\nCONFORMED SUBMISSION TYPE:\t10-K\nCONFIRMING COPY:\t\nPUBLIC DOCUMENT COUNT:\t\t6\nCONFORMED PERIOD OF REPORT:\t19931231\nFILED AS OF DATE:\t\t19940307\n\nFILER:\n\n\tCOMPANY DATA:\t\n\t\tCOMPANY CONFORMED NAME:\t\t\tMINNESOTA MINING & MANUFACTURING CO\n\t\tCENTRAL INDEX KEY:\t\t\t0000066740\n\t\tSTANDARD INDUSTRIAL CLASSIFICATION:\t2670\n\t\tIRS NUMBER:\t\t\t\t410417775\n\t\tSTATE OF INCORPORATION:\t\t\tDE\n\t\tFISCAL YEAR END:\t\t\t1231\n\n\tFILING VALUES:\n\t\tFORM TYPE:\t\t10-K\n\t\tSEC ACT:\t\t34\n\t\tSEC FILE NUMBER:\t001-03285\n\t\tFILM NUMBER:\t\t00000000\n\n\tBUSINESS ADDRESS:\t\n\t\tSTREET 1:\t\t3M CENTER\n\t\tCITY:\t\t\tST PAUL\n\t\tSTATE:\t\t\tMN\n\t\tZIP:\t\t\t55144\n\t\tBUSINESS PHONE:\t\t6127331110\n</IMS-HEADER>\n<DOCUMENT>\n<TYPE>10-K\n<SEQUENCE>1\n<DESCRIPTION>1993 - 10-K\n<TEXT>\n\n                                                                              \n                                  UNITED STATES\n                      SECURITIES AND EXCHANGE COMMISSION\n                            Washington, D.C. 20549\n                                   FORM 10-K\n                                                    \n           [X] ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE\n                        SECURITIES EXCHANGE ACT OF 1934\n                    For the year ended December 31, 1993  \n\n                         Commission file number 1-3285\n\n                  MINNESOTA MINING AND MANUFACTURING COMPANY\n\nState of Incorporation: Delaware   I.R.S. Employer Identification No. 41-0417775\n\n            Executive offices: 3M Center, St. Paul, Minnesota 55144\n                       Telephone number: (612) 733-1110\n                                                     \n          SECURITIES REGISTERED PURSUANT TO SECTION 12(b) OF THE ACT:\n                                                Name of each exchange\n                Title of each class              on which registered \n       Common Stock, Without Par Value          New York Stock Exchange\n                                                Pacific Stock Exchange\n                                                Chicago Stock Exchange\n\nNote:  The  common stock  of the Registrant  is also traded  on the  Amsterdam\nStock Exchange, German stock exchanges, Swiss stock exchanges, the Paris Stock\nExchange and the Tokyo Stock Exchange.\n\n       Securities registered pursuant to section 12(g) of the Act: None\n                                                     \n      Indicate by check mark whether the Registrant (1)  has filed all reports\nrequired to be  filed by Section 13 or 15(d) of the Securities Exchange Act of\n1934  during the  preceding 12  months (or  for such  shorter period  that the\nRegistrant was required to file such reports),  and  (2)  has been  subject to\nsuch filing requirements for the  past 90 days.  Yes    X   . No        .\n\n      Indicate  by check mark if  disclosure of delinquent  filers pursuant to\nItem 405 of Regulation S-K is not contained herein, and will not be contained,\nto  the best  of registrant\'s  knowledge, in  definitive proxy  or information\nstatements  incorporated by  reference in Part  III of  this Form  10-K or any\namendment to this Form 10-K. [  ]\n\n      The aggregate market value of voting stock held by nonaffiliates  of the\nRegistrant, based on the closing price of $107.25 per share as reported on the\nNew  York  Stock  Exchange-Composite Index  on  January  3 ...

# %%
 'https://www.sec.gov/'+doc_list_table.find_all('tr')[-1].find_all('td')[2].find('a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-5b023bbeb277> in <module>
# ----> 1 'https://www.sec.gov/'+doc_list_table.find_all('tr')[-1].find_all('td')[2].find('a')
#
# TypeError: can only concatenate str (not "Tag") to str

# %%
cols_j[1].find('a'
# Out:
# <td nowrap="nowrap"><a href="/Archives/edgar/data/66740/000155837019000470/0001558370-19-000470-index.htm" id="documentsbutton"> Documents</a>  <a href="/cgi-bin/viewer?action=view&amp;cik=66740&amp;accession_number=0001558370-19-000470&amp;xbrl_type=v" id="interactiveDataBtn"> Interactive Data</a></td>

# %%
cols_j[1].find('a',{'href':True, 'id':'documentsbutton'})['href']
# Out:
# '/Archives/edgar/data/66740/000155837019000470/0001558370-19-000470-index.htm'

# %%
cols_j[1].find
# Out:
# <td><label for="type">Filing Type:</label><br/><input id="type" name="type" size="10" tabindex="1" value="10-k"/></td>

# %%
j.find_all('td')[1]
# Out:
# <td><label for="type">Filing Type:</label><br/><input id="type" name="type" size="10" tabindex="1" value="10-k"/></td>

# %%
ten_k_list_table
# Out:
# <table style="margin: 0px; background:#FFFFFF; border: 1px solid #BCD6F8; width: 100%;">
# <tr>
# <td>Filter Results:</td>
# <td><label for="type">Filing Type:</label><br/><input id="type" name="type" size="10" tabindex="1" value="10-k"/></td>
# <td><label for="prior_to">Prior to:</label> (YYYYMMDD)<br/><input id="prior_to" name="dateb" size="10" tabindex="2" value=""/></td>
# <td>Ownership?<br/><input checked="checked" id="include" name="owner" tabindex="3" type="radio" value="include"/><label for="include">include</label><input id="exclude" name="owner" tabindex="4" type="radio" value="exclude"/><label for="exclude">exclude</label><input id="only" name="owner" tabindex="5" type="radio" value="only"><label for="only">only</label>
# <td><label for="count">Limit Results Per Page</label><br/>
# <select id="count" name="count" tabindex="6">
# <option value="10">10 Entries
#                      <option value="20">20 Entries
#                      <option selected="" value="40">40 Entries
#                      <option value="80">80 Entries
#                      <option value="100">100 Entries
#                   </option></option></option></option></option></select>
# </td>
# <td style="text-align: middle;"><input type="submit" value="Search"/><br/><input onclick="this.form.type.value=''" type="submit" value="Show All"/></td>
# </input></td></tr>
# </table>

# %%
doc_table[0].find_all('tr')[1]
# Out:
# <tr>
# <td><a class="external text" href="https://www.nyse.com/quote/XNYS:MMM" rel="nofollow">MMM</a>
# </td>
# <td><a href="/wiki/3M" title="3M">3M Company</a></td>
# <td><a class="external text" href="https://www.sec.gov/cgi-bin/browse-edgar?CIK=MMM&amp;action=getcompany" rel="nofollow">reports</a></td>
# <td>Industrials</td>
# <td>Industrial Conglomerates</td>
# <td><a class="mw-redirect" href="/wiki/St._Paul,_Minnesota" title="St. Paul, Minnesota">St. Paul, Minnesota</a></td>
# <td></td>
# <td>0000066740</td>
# <td>1902
# </td></tr>

# %%
doc_table[0].find_all('tr')[1]
# Out:
# <tr>
# <td><a class="external text" href="https://www.nyse.com/quote/XNYS:MMM" rel="nofollow">MMM</a>
# </td>
# <td><a href="/wiki/3M" title="3M">3M Company</a></td>
# <td><a class="external text" href="https://www.sec.gov/cgi-bin/browse-edgar?CIK=MMM&amp;action=getcompany" rel="nofollow">reports</a></td>
# <td>Industrials</td>
# <td>Industrial Conglomerates</td>
# <td><a class="mw-redirect" href="/wiki/St._Paul,_Minnesota" title="St. Paul, Minnesota">St. Paul, Minnesota</a></td>
# <td></td>
# <td>0000066740</td>
# <td>1902
# </td></tr>

# %%
# Out:
# ['https://www.sec.gov/cgi-bin/browse-edgar?CIK=MMM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ABT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ABBV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ABMD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ACN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ATVI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ADBE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AMD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AAP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AES&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AFL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=A&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=APD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AKAM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ALK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ALB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ARE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ALXN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ALGN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ALLE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AGN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ADS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LNT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ALL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GOOGL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GOOG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AMZN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AMCR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AEE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AAL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AEP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AXP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AIG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AMT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AWK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AMP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ABC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AME&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AMGN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=APH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ADI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ANSS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ANTM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AON&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AOS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=APA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AIV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AAPL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AMAT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=APTV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ADM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ARNC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ANET&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AJG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AIZ&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ATO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=T&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ADSK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ADP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AZO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AVB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AVY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BKR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BLL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BAC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BAX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BDX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BRKB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BBY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BIIB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BLK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BKNG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BWA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BXP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BSX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BMY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=AVGO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BFB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CHRW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=COG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CDNS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CPB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=COF&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CPRI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CAH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KMX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CCL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CAT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CBOE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CBRE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CDW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CNC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CNP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CTL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CERN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CF&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SCHW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CHTR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CVX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CMG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CHD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=XEC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CINF&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CTAS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CSCO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=C&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CFG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CTXS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CLX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CME&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CMS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CTSH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CMCSA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CMA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CAG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CXO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=COP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ED&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=STZ&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=COO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CPRT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GLW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CTVA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=COST&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=COTY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CCI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CSX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CMI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CVS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DHI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DHR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DRI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DVA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DAL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=XRAY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DVN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FANG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DLR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DFS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DISCA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DISCK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DISH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DLTR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=D&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DOV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DOW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DTE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DUK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DRE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DXC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ETFC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EMN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ETN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EBAY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ECL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EIX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EMR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ETR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EOG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EFX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EQIX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EQR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ESS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EVRG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ES&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EXC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EXPE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EXPD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=EXR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=XOM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FFIV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?company=Facebook&owner=exclude&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FAST&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FRT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FDX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FIS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FITB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FRC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FISV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FLT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FLIR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FLS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FMC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=F&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FTNT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FTV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FBHS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FOXA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FOX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=BEN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FCX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GPS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GRMN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GIS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GPC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GILD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GPN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=GWW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HRB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HAL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HBI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HOG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HIG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HAS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HCA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PEAK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HSIC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HSY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HES&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HPE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HLT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HFC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HOLX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HON&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HRL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HST&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HPQ&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HUM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HBAN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=HII&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IEX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IDXX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=INFO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ITW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ILMN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=INTC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ICE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IBM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=INCY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IPG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IFF&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=INTU&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ISRG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IVZ&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IPGP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IQV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=IRM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=JKHY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=J&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=JBHT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SJM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=JNJ&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=JCI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=JPM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=JNPR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KSU&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=K&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KEY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KEYS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KMB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KIM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KMI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KLAC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KSS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KHC&owner=exclude&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=KR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LHX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LRCX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LVS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LEG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LDOS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LEN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LLY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LNC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LIN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LYV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LKQ&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LMT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=L&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LOW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LYB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MTB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=M&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MRO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MPC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MKTX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MAR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MMC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MLM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MAS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MKC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MXIM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MCD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MCK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MDT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MRK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MET&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MTD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MGM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MCHP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MU&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MSFT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MAA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MHK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TAP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?company=Mondelez&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MNST&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MCO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MOS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MSI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MSCI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=MYL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NDAQ&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NOV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NTAP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NFLX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NWL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NEM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NWSA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NWSA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NEE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NLSN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NKE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NBL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=JWN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NSC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NTRS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NOC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NLOK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NCLH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NRG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NUE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NVDA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=NVR&owner=exclude&action=getcompany&Find=Search&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ORLY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=OXY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ODFL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=OMC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=OKE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ORCL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PCAR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PKG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PAYX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PYPL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PNR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PBCT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PEP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PKI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PRGO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PFE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PSX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PNW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PXD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PNC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PPG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PPL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PFG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PGR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PLD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PRU&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PEG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PSA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PHM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PVH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=QRVO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=PWR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=QCOM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DGX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RJF&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RTN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=O&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=REG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=REGN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RF&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RSG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RMD&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RHI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ROK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ROL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ROP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ROST&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=RCL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SPGI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=CRM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SBAC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SLB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=STX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SEE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SRE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=NOW&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SHW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SPG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SWKS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SLG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SNA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=LUV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SWK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SBUX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=STT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=STE&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SYK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SIVB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SYF&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SNPS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=SYY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TMUS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TROW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TTWO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TPR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TGT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TEL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=FTI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TFX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TXN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TXT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TMO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TIF&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TJX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TSCO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TDG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TRV&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TFC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TWTR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=TSN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UDR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ULTA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=USB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UNP&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UAL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UNH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UPS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=URI&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UTX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UHS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=UNM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VFC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VLO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VAR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VTR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VRSN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VRSK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VZ&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VRTX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VIAC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=V&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VNO&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=VMC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WRB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WAB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WMT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WBA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=DIS&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WAT&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WEC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WCG&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WFC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WELL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WDC&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WU&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WRK&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WY&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WHR&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WMB&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WLTW&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=WYNN&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=XEL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=XRX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=XLNX&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=XYL&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=YUM&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ZBRA&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ZBH&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ZION&action=getcompany&type=10-k',
#  'https://www.sec.gov/cgi-bin/browse-edgar?CIK=ZTS&action=getcompany&type=10-k']
